# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(r'C:\Users\Prinzessin\projects\image_data\OCTA_6M\text_labels.csv', sep=";")

df.head(20)
# Out:
#        ID Sex OS/OD  Age Disease  Unnamed: 5
# 0   10001   M    OD   55  NORMAL         NaN
# 1   10002   F    OD   37  OTHERS         NaN
# 2   10003   M    OS   57  OTHERS         NaN
# 3   10004   M    OD   53     AMD         NaN
# 4   10005   M    OS   27      DR         NaN
# 5   10006   F    OS   30  OTHERS         NaN
# 6   10007   M    OD   24  NORMAL         NaN
# 7   10008   F    OD   51     CNV         NaN
# 8   10009   F    OS   61  NORMAL         NaN
# 9   10010   M    OS   49  NORMAL         NaN
# 10  10011   M    OS   36  OTHERS         NaN
# 11  10012   M    OD   64  OTHERS         NaN
# 12  10013   F    OS   56  NORMAL         NaN
# 13  10014   F    OD   56  NORMAL         NaN
# 14  10015   M    OD   64  OTHERS         NaN
# 15  10016   M    OS   59  NORMAL         NaN
# 16  10017   F    OS   58  NORMAL         NaN
# 17  10018   M    OD   36     CNV         NaN
# 18  10019   M    OD   39  OTHERS         NaN
# 19  10020   M    OD   72  OTHERS         NaN

# %%
# Specify the column from which you want to get unique values and count them
column_name = 'Disease'

# Get unique values and their counts
unique_values_counts = df[column_name].value_counts()

# Print the result
print(unique_values_counts)
# Out:
# OTHERS    96
# NORMAL    91
# AMD       43
# DR        35
# CSC       14
# CNV       11
# RVO       10
# Name: Disease, dtype: int64

# %%
import os
import glob
base_path = "../examples/example_data/octa500"

for i, row in df.iterrows():
    path = os.path.join(*[base_path, str(row["ID"]), "*"])
    images = glob.glob(path)
    for image in images:
        pass # print(image)
    
import scipy.io
mat = scipy.io.loadmat(os.path.join(base_path, "10001.mat")    )

# %%
mat['Layer'].shape

# layer, a, b - or b a
# Out:
# (6, 400, 400)

# %%
import matplotlib.pyplot as plt
import cv2

image = cv2.imread(os.path.join(base_path, "10001/400.bmp"))

plt.imshow(image)
plt.plot(mat['Layer'][0, 399])
plt.plot(mat['Layer'][1, 399])
plt.plot(mat['Layer'][2, 399])
plt.plot(mat['Layer'][3, 399])
plt.plot(mat['Layer'][4, 399])
plt.plot(mat['Layer'][5, 399])
#plt.gca().invert_yaxis()
plt.show()

# %%
import pandas as pd

data = pd.read_csv(r"E:\Christina\MIL_Data\octa_whole_octa500_6_faz_unknown\labels\text_labels.csv", delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10688\1535581609.py in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_csv(r"E:\Christina\MIL_Data\octa_whole_octa500_6_faz_unknown\labels\text_labels.csv", delimiter=';')
#
# ~\anaconda3\envs\feta\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data['Disease'].unique()

# %%
data.info

# %%
data['Disease'].value_counts()
