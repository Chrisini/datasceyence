# %%
# All sort of unzip codes

# %%
# https://www.ezyzip.com/unzip-files-online.html

# %%
pwd = b''
filename = 'E:/Christina/octa500/OCTA_6mm_part1.zip'

# %%
from zipfile import ZipFile

with ZipFile(filename) as zf:
    zf.extractall(pwd=pwd)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[37], line 4
#       1 from zipfile import ZipFile
#       3 with ZipFile(filename) as zf:
# ----> 4     zf.extractall(pwd=pwd)
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:1721, in ZipFile.extractall(self, path, members, pwd)
#    1718     path = os.fspath(path)
#    1720 for zipinfo in members:
# -> 1721     self._extract_member(zipinfo, path, pwd)
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:1777, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1774         os.mkdir(targetpath)
#    1775     return targetpath
# -> 1777 with self.open(member, pwd=pwd) as source, \
#    1778      open(targetpath, "wb") as target:
#    1779     shutil.copyfileobj(source, target)
#    1781 return targetpath
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:1646, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1643     else:
#    1644         pwd = None
# -> 1646     return ZipExtFile(zef_file, mode, zinfo, pwd, True)
#    1647 except:
#    1648     zef_file.close()
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:853, in ZipExtFile.__init__(self, fileobj, mode, zipinfo, pwd, close_fileobj)
#     850 self._compress_left = zipinfo.compress_size
#     851 self._left = zipinfo.file_size
# --> 853 self._decompressor = _get_decompressor(self._compress_type)
#     855 self._eof = False
#     856 self._readbuffer = b''
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:752, in _get_decompressor(compress_type)
#     751 def _get_decompressor(compress_type):
# --> 752     _check_compression(compress_type)
#     753     if compress_type == ZIP_STORED:
#     754         return None
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:732, in _check_compression(compression)
#     729         raise RuntimeError(
#     730             "Compression requires the (missing) lzma module")
#     731 else:
# --> 732     raise NotImplementedError("That compression method is not supported")
#
# NotImplementedError: That compression method is not supported

# %%
import py7zlib
class SevenZFile(object):
    @classmethod
    def is_7zfile(cls, filepath):
        '''
        Class method: determine if file path points to a valid 7z archive.
        '''
        is7z = False
        fp = None
        try:
            fp = open(filepath, 'rb')
            archive = py7zlib.Archive7z(fp)
            n = len(archive.getnames())
            is7z = True
        finally:
            if fp:
                fp.close()
        return is7z

    def __init__(self, filepath):
        fp = open(filepath, 'rb')
        self.archive = py7zlib.Archive7z(fp)

    def extractall(self, path):
        for name in self.archive.getnames():
            outfilename = os.path.join(path, name)
            outdir = os.path.dirname(outfilename)
            if not os.path.exists(outdir):
                os.makedirs(outdir)
            outfile = open(outfilename, 'wb')
            outfile.write(self.archive.getmember(name).read())
            outfile.close()

# %%
s = SevenZFile(filename)
# Out:
# ---------------------------------------------------------------------------
# FormatError                               Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s = SevenZFile(filename)
#
# Cell In[38], line 22, in SevenZFile.__init__(self, filepath)
#      20 def __init__(self, filepath):
#      21     fp = open(filepath, 'rb')
# ---> 22     self.archive = py7zlib.Archive7z(fp)
#
# File ~\.conda\envs\feta\Lib\site-packages\py7zlib.py:788, in Archive7z.__init__(self, file, password)
#     786 self.header = file.read(len(MAGIC_7Z))
#     787 if self.header != MAGIC_7Z:
# --> 788     raise FormatError('not a 7z file')
#     789 self.version = unpack('BB', file.read(2))
#     791 self.startheadercrc = unpack('<L', file.read(4))[0]
#
# FormatError: not a 7z file

# %%
import zlib
import base64

def decode_base64_and_inflate( b64string ):
    decoded_data = base64.b64decode( b64string )
    return zlib.decompress( decoded_data , -15)

def deflate_and_base64_encode( string_val ):
    zlibbed_str = zlib.compress( string_val )
    compressed_string = zlibbed_str[2:-4]
    return base64.b64encode( compressed_string )

# %%
import pyzipper

with pyzipper.AESZipFile() as f:
    f.pwd = pwd
    print(f.infolist())
# Out:
# [<AESZipInfo filename='OCTA_6mm/' external_attr=0x10>, <AESZipInfo filename='OCTA_6mm/OCT/' external_attr=0x10>, <AESZipInfo filename='OCTA_6mm/OCT/10001/' external_attr=0x10>, <AESZipInfo filename='OCTA_6mm/OCT/10001/1.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=196366>, <AESZipInfo filename='OCTA_6mm/OCT/10001/10.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=186794>, <AESZipInfo filename='OCTA_6mm/OCT/10001/100.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184869>, <AESZipInfo filename='OCTA_6mm/OCT/10001/101.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185628>, <AESZipInfo filename='OCTA_6mm/OCT/10001/102.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184715>, <AESZipInfo filename='OCTA_6mm/OCT/10001/103.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184657>, <AESZipInfo filename='OCTA_6mm/OCT/10001/104.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184064>, <AESZipInfo filename='OCTA_6mm/OCT/10001/105.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=183891>, <AESZipInfo filename='OCTA_6mm/OCT/10001/106.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184679>, <AESZipInfo filename='OCTA_6mm/OCT/10001/107.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184691>, <AESZipInfo filename='OCTA_6mm/OCT/10001/108.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184134>, <AESZipInfo filename='OCTA_6mm/OCT/10001/109.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184235>, <AESZipInfo filename='OCTA_6mm/OCT/10001/11.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=186734>, <AESZipInfo filename='OCTA_6mm/OCT/10001/110.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184816>, <AESZipInfo filename='OCTA_6mm/OCT/10001/111.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184874>, <AESZipInfo filename='OCTA_6mm/OCT/10001/112.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184600>, <AESZipInfo filename='OCTA_6mm/OCT/10001/113.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184905>, <AESZipInfo filename='OCTA_6mm/OCT/10001/114.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185174>, <AESZipInfo filename='OCTA_6mm/OCT/10001/115.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185405>, <AESZipInfo filename='OCTA_6mm/OCT/10001/116.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185135>, <AESZipInfo filename='OCTA_6mm/OCT/10001/117.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185164>, <AESZipInfo filename='OCTA_6mm/OCT/10001/118.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185385>, <AESZipInfo filename='OCTA_6mm/OCT/10001/119.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185843>, <AESZipInfo filename='OCTA_6mm/OCT/10001/12.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=186886>, <AESZipInfo filename='OCTA_6mm/OCT/10001/120.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185063>, <AESZipInfo filename='OCTA_6mm/OCT/10001/121.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184526>, <AESZipInfo filename='OCTA_6mm/OCT/10001/122.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185193>, <AESZipInfo filename='OCTA_6mm/OCT/10001/123.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=185053>, <AESZipInfo filename='OCTA_6mm/OCT/10001/124.bmp' compress_type=deflate external_attr=0x20 file_size=257078 compress_size=184948>, <AESZipInfo filename='OCTA_6m ...

# %%
from zipfile import ZipFile 

with ZipFile(filename, "r") as zip:
    zip.extractall(path="uncompressed", pwd=pwd.encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 4
#       1 from zipfile import ZipFile
#       3 with ZipFile(filename, "r") as zip:
# ----> 4     zip.extractall(path="uncompressed", pwd=pwd.encode("utf-8"))
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:1721, in ZipFile.extractall(self, path, members, pwd)
#    1718     path = os.fspath(path)
#    1720 for zipinfo in members:
# -> 1721     self._extract_member(zipinfo, path, pwd)
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:1777, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1774         os.mkdir(targetpath)
#    1775     return targetpath
# -> 1777 with self.open(member, pwd=pwd) as source, \
#    1778      open(targetpath, "wb") as target:
#    1779     shutil.copyfileobj(source, target)
#    1781 return targetpath
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:1646, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1643     else:
#    1644         pwd = None
# -> 1646     return ZipExtFile(zef_file, mode, zinfo, pwd, True)
#    1647 except:
#    1648     zef_file.close()
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:853, in ZipExtFile.__init__(self, fileobj, mode, zipinfo, pwd, close_fileobj)
#     850 self._compress_left = zipinfo.compress_size
#     851 self._left = zipinfo.file_size
# --> 853 self._decompressor = _get_decompressor(self._compress_type)
#     855 self._eof = False
#     856 self._readbuffer = b''
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:752, in _get_decompressor(compress_type)
#     751 def _get_decompressor(compress_type):
# --> 752     _check_compression(compress_type)
#     753     if compress_type == ZIP_STORED:
#     754         return None
#
# File ~\.conda\envs\feta\Lib\zipfile\__init__.py:732, in _check_compression(compression)
#     729         raise RuntimeError(
#     730             "Compression requires the (missing) lzma module")
#     731 else:
# --> 732     raise NotImplementedError("That compression method is not supported")
#
# NotImplementedError: That compression method is not supported

# %%
from ZipFile import ZipFile
zip = ZipFile(path)
zip.extractall(pwd=pwd)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from ZipFile import ZipFile
#       2 zip = ZipFile(path)
#       3 zip.extractall(pwd=b'sjed3_oww?3f')
#
# ModuleNotFoundError: No module named 'ZipFile'

# %%
import subprocess

path = "E:/Christina/octa500/OCTA_6mm_part1.zip"

subprocess.call(["7z", "x", "-ppassword", path])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 5
#       1 import subprocess
#       3 path = "E:/Christina/octa500/OCTA_6mm_part1.zip"
# ----> 5 subprocess.call(["7z", "x", "-ppassword", path])
#
# File ~\.conda\envs\feta\Lib\subprocess.py:389, in call(timeout, *popenargs, **kwargs)
#     381 def call(*popenargs, timeout=None, **kwargs):
#     382     """Run command with arguments.  Wait for command to complete or
#     383     timeout, then return the returncode attribute.
#     384
#    (...)
#     387     retcode = call(["ls", "-l"])
#     388     """
# --> 389     with Popen(*popenargs, **kwargs) as p:
#     390         try:
#     391             return p.wait(timeout=timeout)
#
# File ~\.conda\envs\feta\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\.conda\envs\feta\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
from pyunpack import Archive
Archive('C:/Users/Christina/Downloads/normal.rar').extractall('E:/Christina/Sample_Data/onh_Mokhtary')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from pyunpack import Archive
#       2 Archive('C:/Users/Christina/Downloads/normal.rar').extractall('E:/Christina/Sample_Data/onh_Mokhtary')
#
# ModuleNotFoundError: No module named 'pyunpack'

# %%
import rarfile

rf = rarfile.RarFile("C:/Users/Christina/Downloads/normal.rar")
for f in rf.infolist():
    print(f.filename, f.file_size)
    if f.filename == "README":
        print(rf.read(f))
# Out:
# normal/2_od.mat 9441743
# normal/2_os.mat 9367927
# normal/3_os.mat 9045864
# normal/3_od.mat 8537782
# normal/4_od.mat 9919662
# normal/4_os.mat 10264944
# normal/5_od.mat 9460764
# normal/5_os.mat 9210971
# normal/6_od.mat 8502201
# normal/6_os.mat 8263531
# normal/7_os.mat 9304614
# normal/7_od.mat 9353919
# normal/1_od.mat 9468082
# normal/1_os.mat 9423830
# normal/ 0

# %%
from zipfile import ZipFile

z = rarfile.RarFile("C:/Users/Christina/Downloads/normal.rar", 'r')
z.extractall('E:/Christina/Sample_Data/onh_Mokhtary')
z.close()

# %%
import scipy.io as sio

# Load the .mat file
data = sio.loadmat('E:/Christina/Sample_Data/onh_Mokhtary/1p/1p.mat')

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Sun Oct 30 12:32:36 2011',
#  '__version__': '1.0',
#  '__globals__': [],
#  'd5': array([[[70, 57, 21, ..., 58, 57, 56],
#          [67, 58, 59, ..., 72, 55, 66],
#          [70, 58, 55, ..., 57, 53, 63],
#          ...,
#          [ 0, 61, 44, ..., 66, 51, 25],
#          [ 0, 60, 53, ..., 52, 54, 44],
#          [ 0, 52, 63, ..., 68, 70, 58]],
#
#         [[ 5, 50, 64, ..., 56, 58, 58],
#          [64, 64, 63, ..., 60, 68, 48],
#          [59, 53, 34, ..., 43, 57, 73],
#          ...,
#          [51, 69, 70, ..., 53, 47, 39],
#          [18, 64, 46, ..., 64, 59, 70],
#          [53, 62, 53, ..., 69, 36, 58]],
#
#         [[64, 49, 63, ..., 59, 74, 43],
#          [78, 60, 55, ..., 61, 55, 50],
#          [51, 45, 63, ..., 50, 61, 58],
#          ...,
#          [59, 44, 51, ..., 49, 61, 46],
#          [44, 52, 61, ..., 72, 55, 60],
#          [54, 69, 60, ..., 64, 66, 43]],
#
#         ...,
#
#         [[61, 55, 48, ..., 42, 62, 60],
#          [58, 50, 54, ..., 47, 61, 57],
#          [55, 61, 57, ..., 65, 32, 50],
#          ...,
#          [35, 67, 59, ..., 38, 59, 57],
#          [43, 56, 39, ..., 60, 58, 53],
#          [58, 59, 47, ..., 58, 62, 61]],
#
#         [[70, 63, 57, ..., 29, 27, 77],
#          [71, 55, 60, ..., 64, 56, 62],
#          [77, 58, 55, ..., 51, 48, 47],
#          ...,
#          [53, 50, 62, ..., 56, 61, 50],
#          [61, 68, 53, ..., 71, 53, 50],
#          [57, 54, 60, ..., 20, 66, 72]],
#
#         [[69, 63, 44, ..., 50, 54, 56],
#          [57, 55, 65, ..., 58, 55, 71],
#          [67, 34, 57, ..., 60, 56, 63],
#          ...,
#          [53, 55, 56, ..., 60, 55, 53],
#          [63, 60, 47, ..., 51, 56, 56],
#          [70, 62, 30, ..., 54, 49, 60]]], dtype=uint8)}

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# Access the variable 'data' from the loaded .mat file
data_array = data['d5']# [:,:,0]

img_file = data_array # .reshape((650, 128, 512)).T
            
bscan_slices = []


ascans = 650
depth = 512
bscans = 128


for i, bscan_slice in enumerate(np.rollaxis(img_file, 2)):
    # ========== 2 ==========

    # transform each bscan
    #bscan_slice = np.rot90(bscan_slice) # Rotating image 90 deg CCW
    #bscan_slice = np.fliplr(bscan_slice) # Flipping image horizontally

    #print(mode["dst_depth_px"])
    #print(mode["ascan"])

    bscan_slice = cv2.resize(bscan_slice, (ascans, bscans)) # Resizing image
    
    
    plt.figure(figsize=(8, 6))
    plt.imshow(bscan_slice)
    plt.title('Data Plot')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid(True)
    plt.show()
    
    
    # append bscans or SAVE IMAGE HERE (the slice)
    bscan_slices.append(bscan_slice)

# stack bscans
bscan_file = np.stack(bscan_slices, axis=0) 

enface_file = np.zeros(shape = (bscans, ascans), dtype = np.uint8) # todo was 500, 500 before ... a or b first?

# ========== 2 ==========
for i, bscan in enumerate(bscan_file):                  
    enfacedata = np.amax(bscan, axis=0) # Obtaining max value in each row and generating a n-by-1 matrix
    enface_file[i] = enfacedata # Appending enfacedata to the enface array

enface_file = cv2.resize(enface_file, (500, 500))
    
# Plot the data (adjust as needed)
plt.figure(figsize=(8, 6))
plt.imshow(enface_file, cmap="gray")
plt.title('Data Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
data['d5'].shape
# Out:
# (650, 512, 128)

# %%
380928 / 496 / 768
# Out:
# 1.0

# %%
tarfile.is_tarfile('C:/Users/Christina/Downloads/label.zip')
# Out:
# False
