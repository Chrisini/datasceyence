# %%
import pandas as pd
import os

# %%
path_a = r'C:\Users\Prinzessin\projects\decentnet\datasceyence\examples\example_results\lightning_logs\debug_oct_no_fc\version_15'
path_b = r'C:\Users\Prinzessin\projects\decentnet\datasceyence\examples\example_results\lightning_logs\dumpster\version_26'

# %%
file = 'metrics.csv'
#file = 'out_final_test.csv'
#file_a = 'out_2.csv'

# %%
df_a = pd.read_csv(os.path.join(path_a, file_a))

df_b = pd.read_csv(os.path.join(path_b, file))

df_a.info(), df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   source        41 non-null     object
#  1   target        41 non-null     object
#  2   target_group  41 non-null     object
#  3   value         41 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   test_acc   1 non-null      float64
#  1   test_f1    1 non-null      float64
#  2   test_prec  1 non-null      float64
#  3   test_loss  1 non-null      float64
#  4   test_cc    1 non-null      float64
#  5   epoch      1 non-null      int64
#  6   step       1 non-null      int64
# dtypes: float64(5), int64(2)
# memory usage: 184.0 bytes
# (None, None)

# %%
df_b
# Out:
#    test_acc  test_f1  test_prec  test_loss   test_cc  epoch  step
# 0     0.375    0.375      0.225   1.353913  4.446337      0     0

# %%
a = pd.concat([df_a, df_b], axis=1)

# %%
a
# Out:
#    source target target_group     value  test_acc  test_f1  test_prec  \
# 0     0_0  10_10      decent1  0.684380     0.375    0.375      0.225
# 1     0_0    1_6      decent1  0.722644       NaN      NaN        NaN
# 2     0_0    2_1      decent1  0.486219       NaN      NaN        NaN
# 3     0_0  13_11      decent1  0.683856       NaN      NaN        NaN
# 4   10_10   10_5      decent2  0.313974       NaN      NaN        NaN
# 5     2_1   13_0      decent2  0.290580       NaN      NaN        NaN
# 6   10_10   13_6      decent2  0.298153       NaN      NaN        NaN
# 7     1_6   13_6      decent2  0.300071       NaN      NaN        NaN
# 8     1_6    9_7      decent2  0.359126       NaN      NaN        NaN
# 9     2_1    9_7      decent2  0.286706       NaN      NaN        NaN
# 10  13_11    9_7      decent2  0.273956       NaN      NaN        NaN
# 11   13_6    7_3      decent3  0.374516       NaN      NaN        NaN
# ...

# %%
a['val_loss']
# Out:
# 0         NaN
# 1    1.571964
# 2         NaN
# 3         NaN
# 4    1.282192
# 5         NaN
# 6         NaN
# 7    1.782814
# 8         NaN
# 9         NaN
# Name: val_loss, dtype: float64

# %%
a['test_loss']
# Out:
#    test_loss  test_loss
# 0        NaN   1.427124
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8        NaN        NaN
# 9   1.427124        NaN
