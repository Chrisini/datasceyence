# %% [markdown]
# # MUNIT

# %% [markdown]
# ## Data preparation

# %%
import glob
import pandas as pd
from sklearn.model_selection import train_test_split



if True:
    
    # write list to binary file
    def write_list(a_list, a_filename):
        
        df = pd.DataFrame(a_list, columns=['paths'])
        df.to_csv(a_filename, header=False, index=False)

        
    cirrus_paths = glob.glob("E:/Christina/Result_Data/CIRRUS_*/enface/*_cube_z.tif")
    fundus_paths = glob.glob("E:/Christina/Result_Data/ADAM_*/fundus/*jpg")
    
    cirrus_paths_train, cirrus_paths_test = train_test_split(cirrus_paths, test_size=20)
    fundus_paths_train, fundus_paths_test = train_test_split(fundus_paths, test_size=20)
    
    data_list_train_cirrus = "munit/datasets/cirrus_train.txt"
    data_list_test_cirrus  = "munit/datasets/cirrus_test.txt"
    data_list_train_fundus = "munit/datasets/fundus_train.txt"
    data_list_test_fundus  = "munit/datasets/fundus_test.txt"
    
    
    write_list(cirrus_paths_train, data_list_train_cirrus)
    write_list(cirrus_paths_test, data_list_test_cirrus)
    write_list(fundus_paths_train, data_list_train_fundus)
    write_list(fundus_paths_test, data_list_test_fundus)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11356\1373034650.py in <cell line: 10>()
#      17     fundus_paths = glob.glob("E:/Christina/Result_Data/ADAM_*/fundus/*jpg")
#      18
# ---> 19     cirrus_paths_train, cirrus_paths_test = train_test_split(cirrus_paths, test_size=20)
#      20     fundus_paths_train, fundus_paths_test = train_test_split(fundus_paths, test_size=20)
#      21
#
# ~\anaconda3\envs\feta\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2431
#    2432     n_samples = _num_samples(arrays[0])
# -> 2433     n_train, n_test = _validate_shuffle_split(
#    2434         n_samples, test_size, train_size, default_test_size=0.25
#    2435     )
#
# ~\anaconda3\envs\feta\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2054         and (test_size <= 0 or test_size >= 1)
#    2055     ):
# -> 2056         raise ValueError(
#    2057             "test_size={0} should be either positive and smaller"
#    2058             " than the number of samples {1} or a float in the "
#
# ValueError: test_size=20 should be either positive and smaller than the number of samples 0 or a float in the (0, 1) range

# %% [markdown]
# # Train

# %%
"""
Copyright (C) 2018 NVIDIA Corporation.  All rights reserved.
Licensed under the CC BY-NC-SA 4.0 license (https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode).
"""

# vgg_preprocess needs a device

import os
import sys
import shutil

from munit.trainer import MUNIT_Trainer, UNIT_Trainer
from munit.utils import get_all_data_loaders, prepare_sub_folder, write_html, write_loss, get_config, write_2images, Timer

import torch
import torch.nn
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

import tensorboardX

config_file = 'munit/configs/img2img_list.yaml'
output_path = 'munit/results'
trainer = "MUNIT" # or UNIT

device = "cuda"
resume = False

# Load experiment setting
config = get_config(config_file)
max_iter = config['max_iter']
display_size = config['display_size']
config['vgg_model_path'] = output_path

# Setup model and data loader
if trainer == 'MUNIT':
    trainer = MUNIT_Trainer(config, device)
elif trainer == 'UNIT':
    trainer = UNIT_Trainer(config)
else:
    sys.exit("Only support MUNIT|UNIT")
trainer.to(device)
train_loader_a, train_loader_b, test_loader_a, test_loader_b = get_all_data_loaders(config)
train_display_images_a = torch.stack([train_loader_a.dataset[i] for i in range(display_size)]).to(device)
train_display_images_b = torch.stack([train_loader_b.dataset[i] for i in range(display_size)]).to(device)
test_display_images_a = torch.stack([test_loader_a.dataset[i] for i in range(display_size)]).to(device)
test_display_images_b = torch.stack([test_loader_b.dataset[i] for i in range(display_size)]).to(device)

# Setup logger and output folders
model_name = os.path.splitext(os.path.basename(config_file))[0]
train_writer = tensorboardX.SummaryWriter(os.path.join(output_path + "/logs", model_name))
output_directory = os.path.join(output_path + "/outputs", model_name)
checkpoint_directory, image_directory = prepare_sub_folder(output_directory)
shutil.copy(config_file, os.path.join(output_directory, 'config.yaml')) # copy config file to output folder

# Start training
start_iter = trainer.resume(checkpoint_directory, hyperparameters=config) # if resume else 0

for iterations in range(start_iter, max_iter):
    for i_batch, (images_a, images_b) in enumerate(zip(train_loader_a, train_loader_b)):
        
        
        images_a, images_b = images_a.to(device).detach(), images_b.to(device).detach()

        #with Timer("Elapsed time in update: %f"):
        # Main training code
        trainer.dis_update(images_a, images_b, config)
        trainer.gen_update(images_a, images_b, config)
        torch.cuda.synchronize()
            
        trainer.update_learning_rate()

    print("This Iteration: %08d/%d" % (iterations, max_iter))
    
    # log stuff
    if iterations % config['image_save_iter'] == 0: # config['image_save_iter']

            print("Save Iteration: %08d/%d" % (iterations, max_iter))
            write_loss(iterations, trainer, train_writer)

            # Write images
            with torch.no_grad():
                test_image_outputs = trainer.sample(test_display_images_a, test_display_images_b)
                train_image_outputs = trainer.sample(train_display_images_a, train_display_images_b)
            write_2images(test_image_outputs, display_size, image_directory, 'test_%08d' % (iterations + 1))
            write_2images(train_image_outputs, display_size, image_directory, 'train_%08d' % (iterations + 1))
            # HTML
            write_html(output_directory + "/index.html", iterations + 1, config['image_save_iter'], 'images')

            # save images
            with torch.no_grad():
                image_outputs = trainer.sample(train_display_images_a, train_display_images_b)
            write_2images(image_outputs, display_size, image_directory, 'train_current')

            # Save network weights
            trainer.save(checkpoint_directory, iterations)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24556\831117191.py in <cell line: 43>()
#      41     sys.exit("Only support MUNIT|UNIT")
#      42 trainer.to(device)
# ---> 43 train_loader_a, train_loader_b, test_loader_a, test_loader_b = get_all_data_loaders(config)
#      44 train_display_images_a = torch.stack([train_loader_a.dataset[i] for i in range(display_size)]).to(device)
#      45 train_display_images_b = torch.stack([train_loader_b.dataset[i] for i in range(display_size)]).to(device)
#
# ~\projects\decentnet\datasceyence\examples\munit\utils.py in get_all_data_loaders(conf)
#      65                                              new_size_b, new_size_b, new_size_b, num_workers, True)
#      66     else:
# ---> 67         train_loader_a = get_data_loader_list(conf['data_folder_train_a'], conf['data_list_train_a'], batch_size, True,
#      68                                                 new_size_a, height, width, num_workers, True)
#      69         test_loader_a = get_data_loader_list(conf['data_folder_test_a'], conf['data_list_test_a'], batch_size, False,
#
# ~\projects\decentnet\datasceyence\examples\munit\utils.py in get_data_loader_list(root, file_list, batch_size, train, new_size, height, width, num_workers, crop)
#      86     transform_list = [transforms.RandomHorizontalFlip()] + transform_list if train else transform_list
#      87     transform = transforms.Compose(transform_list)
# ---> 88     dataset = ImageFilelist(root, file_list, transform=transform)
#      89     loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=train, drop_last=True, num_workers=num_workers)
#      90     return loader
#
# ~\projects\decentnet\datasceyence\examples\munit\data.py in __init__(self, root, flist, transform, flist_reader, loader)
#      27                  flist_reader=default_flist_reader, loader=default_loader):
#      28         self.root = root
# ---> 29         self.imlist = flist_reader(flist)
#      30         self.transform = transform
#      31         self.loader = loader
#
# ~\projects\decentnet\datasceyence\examples\munit\data.py in default_flist_reader(flist)
#      15     """
#      16     imlist = []
# ---> 17     with open(flist, 'r') as rf:
#      18         for line in rf.readlines():
#      19             impath = line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'munit/datasets/fundus_train.txt'

# %%
"""
Copyright (C) 2018 NVIDIA Corporation.  All rights reserved.
Licensed under the CC BY-NC-SA 4.0 license (https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode).
"""

# vgg_preprocess needs a device

import os
import sys
import shutil

from munit.trainer import MUNIT_Trainer, UNIT_Trainer
from munit.utils import get_all_data_loaders, prepare_sub_folder, write_html, write_loss, get_config, write_2images, Timer

import torch
import torch.nn
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

import tensorboardX

config_file = 'munit/configs/img2img_list.yaml'
output_path = 'munit/results'
trainer = "MUNIT" # or UNIT

device = "cuda"
resume = False

# Load experiment setting
config = get_config(config_file)
max_iter = config['max_iter']
display_size = config['display_size']
config['vgg_model_path'] = output_path

# Setup model and data loader
trainer = MUNIT_Trainer(config, device)

trainer.to(device)

# Setup logger and output folders
model_name = os.path.splitext(os.path.basename(config_file))[0]
train_writer = tensorboardX.SummaryWriter(os.path.join(output_path + "/logs", model_name))
output_directory = "D:/cir plex"
checkpoint_directory, image_directory = prepare_sub_folder(output_directory)
shutil.copy(config_file, os.path.join(output_directory, 'config.yaml')) # copy config file to output folder

# Start training
start_iter = trainer.resume(checkpoint_directory, hyperparameters=config) if resume else 0

# %% [markdown]
# # Inference

# %%
import os

# %%
"""
Copyright (C) 2018 NVIDIA Corporation.  All rights reserved.
Licensed under the CC BY-NC-SA 4.0 license (https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode).
"""
# from __future__ import print_function
from munit.utils import get_config, pytorch03_to_pytorch04
from munit.trainer import MUNIT_Trainer, UNIT_Trainer
from torch.autograd import Variable
import torchvision.utils as vutils
import sys
import torch
import os
from torchvision import transforms
from PIL import Image

config_file = 'munit/configs/img2img_list.yaml'
output_folder = 'E:/plex_to_cirrus_munit'
trainer = "MUNIT" # or UNIT

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Load experiment setting
config = get_config(config_file)
num_style = 1 # if opts.style != '' else opts.num_style

# Setup model and data loader
config['vgg_model_path'] = output_folder

style_dim = config['gen']['style_dim']
trainer = MUNIT_Trainer(config)

checkpoint = "MUNIT/results/ckpt/plex_cir/gen_00000201.pt"

try:
    state_dict = torch.load(checkpoint)
    trainer.gen_a.module.load_state_dict(state_dict['a'])
    trainer.gen_b.module.load_state_dict(state_dict['b'])
except:
    state_dict = pytorch03_to_pytorch04(torch.load(checkpoint), trainer)
    trainer.gen_a.module.load_state_dict(state_dict['a'])
    trainer.gen_b.module.load_state_dict(state_dict['b'])

trainer.cuda()
trainer.eval()
encode = trainer.gen_b.module.encode # if opts.a2b else trainer.gen_b.encode # encode function
style_encode = trainer.gen_a.module.encode # if opts.a2b else trainer.gen_a.encode # encode function
decode = trainer.gen_a.module.decode # if opts.a2b else trainer.gen_a.decode # decode function

new_size = 256 # config['new_size']

import glob
content_paths = glob.glob("E:/enface_plex/*")
style_paths = glob.glob("D:/Christina/Results_Data/CIRRUS_Glaucoma/enface/*_cube*")
import random

for image_id, content_path in enumerate(content_paths):

    with torch.no_grad():
        transform = transforms.Compose([transforms.Resize(new_size),
                                        transforms.ToTensor(),
                                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
        
        
        #content_path = "C:/snec_data/Result_Data/plex/enface/enface_SAMPLE_Angio (6mmx6mm)_7-31-2019_10-51-21_OD_sn0027_cube_z.tif"
        style_path = random.choice(style_paths) # "C:/snec_data/Result_Data/cirrus/enface/enface_PSNASERI0096_Angiography 6x6 mm_10-3-2018_14-42-42_OD_sn1080_cube_z.tif"
        #style = "E:/enface_PSNASERI0003_Angiography 6x6 mm_7-3-2018_10-24-16_OS_sn0029_cube_z.tif"
        #input_path = "C:/Users/Prinzessin/projects/image_data/iChallenge_AMD_OD_Fovea_lesions/ADAM_400_testset/V0001.jpg"
        # style = "C:/Users/Prinzessin/Documents/gray.png"

        

        print(content_path)

        content_image = Variable(transform(Image.open(content_path).convert('RGB')).unsqueeze(0).cuda()) 
        style_image = Variable(transform(Image.open(style_path).convert('RGB')).unsqueeze(0).cuda()) # if style != '' else None
        # Variable(transform(Image.open(style).convert('RGB')).unsqueeze(0).cuda()) if style != '' else None
        # Variable(transform(Image.open(input_path).convert('RGB')).unsqueeze(0).cuda())
        
        """
        device = "cuda"
        # Write images
        with torch.no_grad():

            s_a1 = Variable(torch.randn(1, 8, 1, 1).to(device))
            s_b1 = Variable(torch.randn(1, 8, 1, 1).to(device))
            s_a2 = Variable(torch.randn(x_a.size(0), 8, 1, 1).to(device))
            s_b2 = Variable(torch.randn(x_b.size(0), 8, 1, 1).to(device))
            x_a_recon, x_b_recon, x_ba1, x_ba2, x_ab1, x_ab2 = [], [], [], [], [], []
            for i in range(x_a.size(0)):
                c_a, s_a_fake = trainer.gen_a.module.encode(x_a[i].unsqueeze(0))
                c_b, s_b_fake = trainer.gen_b.module.encode(x_b[i].unsqueeze(0))
                x_a_recon.append(trainer.gen_a.module.decode(c_a, s_a_fake))
                x_b_recon.append(trainer.gen_b.module.decode(c_b, s_b_fake))
                x_ba1.append(trainer.gen_a.module.decode(c_b, s_a1[i].unsqueeze(0)))
                x_ba2.append(trainer.gen_a.module.decode(c_b, s_a2[i].unsqueeze(0)))
                x_ab1.append(trainer.gen_b.module.decode(c_a, s_b1[i].unsqueeze(0)))
                x_ab2.append(trainer.gen_b.module.decode(c_a, s_b2[i].unsqueeze(0)))
            x_a_recon, x_b_recon = torch.cat(x_a_recon), torch.cat(x_b_recon)
            x_ba1, x_ba2 = torch.cat(x_ba1), torch.cat(x_ba2)
            x_ab1, x_ab2 = torch.cat(x_ab1), torch.cat(x_ab2)

            vutils.save_image(x_ab1.data, os.path.join(output_folder, 'x_ab1.jpg'), padding=0, normalize=True)
            vutils.save_image(x_ba1.data, os.path.join(output_folder, 'x_ba1.jpg'), padding=0, normalize=True)
            #return x_a, x_a_recon, x_ab1, x_ab2, x_b, x_b_recon, x_ba1, x_ba2
        """
        
        
        
        # Start testing
        content, _ = encode(content_image)

        #print(content.shape)



        

        #print(style_rand)
        #print(content.permute(2,3,1,0).squeeze()[:,:,5].shape)

        # vutils.save_image(content.permute(2,3,1,0).squeeze()[:,:,10].data, os.path.join(output_folder, 'a.jpg'), padding=0, normalize=True)

        if False: #style != '':
            _, style = style_encode(style_image)

        if True: # else:
            style_rand = Variable(torch.randn(num_style, style_dim, 1, 1).cuda())
            style = style_rand

        #print(style.shape)

        #print(style)

        #for j in range(num_style):
        j = 0
        s = style[j].unsqueeze(0)
        outputs = decode(content, s)
        
        print(outputs.shape)
        
        # outputs = (outputs + 1) / 2.
        path = os.path.join(output_folder, 'output_img{:03d}.jpg'.format(image_id))
        
        
        print(outputs.shape)
        
        invTrans = transforms.Compose([ transforms.Normalize(mean = [ 0., 0., 0. ],
                                                     std = [ 1/0.5, 1/0.5, 1/0.5 ]),
                                transforms.Normalize(mean = [ -0.5, -0.5, -0.5 ],
                                                     std = [ 1., 1., 1. ]),
                               ])

        outputs = invTrans(outputs)
        
        
        
        vutils.save_image(outputs.data, path, padding=0, normalize=False)

        # also save input images
        # vutils.save_image(content_image.data, os.path.join(output_folder, 'input.jpg'), padding=0, normalize=True)
# Out:
# E:/enface_plex\PREMODEL_HTN_851_Angio (6mmx6mm)_4-1-2022_14-47-25_OS_sn1861_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_851_Angio (6mmx6mm)_4-1-2022_14-41-21_OD_sn1856_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_849_Angio (6mmx6mm)_3-9-2022_16-26-12_OS_sn1838_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_849_Angio (6mmx6mm)_3-9-2022_16-22-50_OD_sn1834_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_848_Angio (6mmx6mm)_3-9-2022_10-47-16_OS_sn1830_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_848_Angio (6mmx6mm)_3-9-2022_10-38-17_OD_sn1826_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_846_Angio (6mmx6mm)_3-1-2022_15-2-56_OS_sn1803_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_846_Angio (6mmx6mm)_3-1-2022_14-59-58_OD_sn1800_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_845_Angio (6mmx6mm)_2-16-2022_14-21-25_OS_sn1797_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_845_Angio (6mmx6mm)_2-16-2022_14-17-42_OD_sn1793_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_844_Angio (6mmx6mm)_2-15-2022_14-51-6_OS_sn1789_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_844_Angio (6mmx6mm)_2-15-2022_14-47-32_OD_sn1785_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_842_Angio (6mmx6mm)_1-18-2022_10-43-12_OS_sn1768_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_842_Angio (6mmx6mm)_1-18-2022_10-31-24_OD_sn1761_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_841_Angio (6mmx6mm)_12-29-2021_14-8-48_OS_sn1738_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_841_Angio (6mmx6mm)_12-29-2021_14-8-0_OD_sn1737_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_840_Angio (6mmx6mm)_12-14-2021_14-49-48_OS_sn1721_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_840_Angio (6mmx6mm)_12-14-2021_14-48-40_OD_sn1720_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_839_Angio (6mmx6mm)_12-13-2021_12-7-35_OD_sn1711_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_839_Angio (6mmx6mm)_12-13-2021_12-11-6_OS_sn1713_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_838_Angio (6mmx6mm)_11-26-2021_11-20-7_OS_sn1703_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_838_Angio (6mmx6mm)_11-26-2021_11-12-28_OD_sn1698_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_836_Angio (6mmx6mm)_11-18-2021_14-58-21_OS_sn1673_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_835_Angio (6mmx6mm)_11-12-2021_15-15-38_OS_sn1657_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_835_Angio (6mmx6mm)_11-12-2021_14-50-15_OD_sn1653_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_832_Angio (6mmx6mm)_10-28-2021_10-9-3_OS_sn1584_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_832_Angio (6mmx6mm)_10-28-2021_10-8-5_OD_sn1583_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_831_Angio (6mmx6mm)_10-26-2021_11-2-57_OS_sn1558_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_831_Angio (6mmx6mm)_10-26-2021_10-54-5_OD_sn1552_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_830_Angio (6mmx6mm)_10-22-2021_14-32-54_OS_sn1542_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_830_Angio (6mmx6mm)_10-22-2021_14-31-5_OD_sn1540_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_829_Angio (6mmx6mm)_10-22-2021_14-22-43_OS_sn1535_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_829_Angio (6mmx6mm)_10-22-2021_14-16-7_OD_sn1529_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_825_Angio (6mmx6mm)_8-24-2021_12-23-34_OS_sn1456_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_825_Angio (6mmx6mm)_8-24-2021_12-16-23_OD_sn1451_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_824_Angio (6mmx6mm)_11-24-2021_12-57-42_OS_sn1694_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_824_Angio (6mmx6mm)_11-24-2021_12-51-59_OD_sn1689_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_823_Angio (6mmx6mm)_8-30-2021_12-12-33_OS_sn1463_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_822_Angio (6mmx6mm)_8-16-2021_14-36-15_OS_sn1439_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_822_Angio (6mmx6mm)_8-16-2021_14-32-29_OD_sn1435_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_821_Angio (6mmx6mm)_8-17-2021_10-30-2_OS_sn1447_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_821_Angio (6mmx6mm)_8-17-2021_10-26-36_OD_sn1443_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_818_Angio (6mmx6mm)_8-4-2021_10-3-17_OS_sn1427_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_815_Angio (6mmx6mm)_7-21-2021_10-52-32_OS_sn1419_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_815_Angio (6mmx6mm)_7-21-2021_10-47-31_OD_sn1414_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_814_Angio (6mmx6mm)_7-16-2021_13-29-59_OS_sn1412_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_814_Angio (6mmx6mm)_7-16-2021_13-20-31_OD_sn1406_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_812_Angio (6mmx6mm)_7-12-2021_10-44-44_OS_sn1402_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_812_Angio (6mmx6mm)_7-12-2021_10-38-0_OD_sn1397_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_809_Angio (6mmx6mm)_6-8-2021_9-37-49_OS_sn1362_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_809_Angio (6mmx6mm)_6-8-2021_9-29-42_OD_sn1357_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_805_Angio (6mmx6mm)_6-8-2021_13-51-20_OS_sn1370_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_805_Angio (6mmx6mm)_6-8-2021_13-47-14_OD_sn1366_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_801_Angio (6mmx6mm)_5-4-2021_10-55-49_OS_sn1354_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_801_Angio (6mmx6mm)_5-4-2021_10-52-39_OD_sn1350_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_799_Angio (6mmx6mm)_4-13-2021_10-39-32_OS_sn1321_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_799_Angio (6mmx6mm)_4-13-2021_10-35-46_OD_sn1317_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_798_Angio (6mmx6mm)_4-19-2021_10-31-22_OS_sn1329_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_798_Angio (6mmx6mm)_4-19-2021_10-28-5_OD_sn1325_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_797_Angio (6mmx6mm)_4-8-2021_15-6-6_OS_sn1313_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_797_Angio (6mmx6mm)_4-8-2021_15-1-4_OD_sn1309_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_795_Angio (6mmx6mm)_4-26-2021_14-42-1_OD_sn1343_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_795_Angio (6mmx6mm)_4-26-2021_14-40-50_OS_sn1342_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_793_Angio (6mmx6mm)_10-29-2021_15-56-45_OS_sn1602_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_793_Angio (6mmx6mm)_10-29-2021_15-47-37_OD_sn1596_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_792_Angio (6mmx6mm)_3-9-2021_14-58-15_OD_sn1275_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_791_Angio (6mmx6mm)_4-8-2021_10-57-45_OS_sn1305_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_791_Angio (6mmx6mm)_4-8-2021_10-51-20_OD_sn1300_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_790_Angio (6mmx6mm)_3-12-2021_15-6-52_OS_sn1288_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_790_Angio (6mmx6mm)_3-12-2021_15-3-30_OD_sn1284_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_788_Angio (6mmx6mm)_4-26-2021_10-45-26_OS_sn1338_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_788_Angio (6mmx6mm)_4-26-2021_10-40-41_OD_sn1333_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_786_Angio (6mmx6mm)_2-25-2021_15-40-44_OD_sn1226_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_785_Angio (6mmx6mm)_2-10-2021_10-27-11_OS_sn1222_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_785_Angio (6mmx6mm)_2-10-2021_10-22-51_OD_sn1218_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_784_Angio (6mmx6mm)_11-9-2021_14-37-1_OS_sn1637_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_783_Angio (6mmx6mm)_2-2-2021_12-8-3_OS_sn1214_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_783_Angio (6mmx6mm)_2-2-2021_12-3-37_OD_sn1210_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_782_Angio (6mmx6mm)_3-15-2021_10-36-50_OS_sn1296_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_782_Angio (6mmx6mm)_3-15-2021_10-33-18_OD_sn1292_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_780_Angio (6mmx6mm)_1-26-2021_11-2-12_OD_sn1201_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_780_Angio (6mmx6mm)_1-26-2021_11-10-21_OS_sn1205_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_776_Angio (6mmx6mm)_12-16-2020_14-35-14_OS_sn1163_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_776_Angio (6mmx6mm)_12-16-2020_14-31-3_OD_sn1159_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_773_Angio (6mmx6mm)_11-13-2020_10-18-18_OS_sn1107_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_773_Angio (6mmx6mm)_11-13-2020_10-17-11_OD_sn1106_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_772_Angio (6mmx6mm)_11-20-2020_14-29-32_OS_sn1127_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_772_Angio (6mmx6mm)_11-20-2020_14-27-44_OD_sn1126_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_771_Angio (6mmx6mm)_1-14-2022_16-4-6_OS_sn1759_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_771_Angio (6mmx6mm)_1-14-2022_15-58-0_OD_sn1755_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_771_Angio (6mmx6mm)_11-18-2020_10-52-29_OS_sn1117_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_771_Angio (6mmx6mm)_11-18-2020_10-45-51_OD_sn1114_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_770_Angio (6mmx6mm)_11-1-2021_15-21-4_OS_sn1628_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_770_Angio (6mmx6mm)_11-1-2021_15-20-9_OD_sn1627_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_769_Angio (6mmx6mm)_11-3-2021_14-47-15_OS_sn1608_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_769_Angio (6mmx6mm)_11-3-2021_14-46-16_OD_sn1607_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_769_Angio (6mmx6mm)_10-15-2020_14-39-11_OD_sn1089_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_766_Angio (6mmx6mm)_1-19-2022_11-25-44_OS_sn1779_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_766_Angio (6mmx6mm)_1-19-2022_11-15-32_OD_sn1775_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_763_Angio (6mmx6mm)_11-17-2021_10-36-2_OS_sn1663_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_763_Angio (6mmx6mm)_11-17-2021_10-34-19_OD_sn1662_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_762_Angio (6mmx6mm)_10-11-2021_10-22-11_OS_sn1510_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_762_Angio (6mmx6mm)_10-11-2021_10-15-24_OD_sn1505_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_760_Angio (6mmx6mm)_9-9-2020_10-22-38_OS_sn1041_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_753_Angio (6mmx6mm)_3-1-2021_11-9-29_OD_sn1251_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_753_Angio (6mmx6mm)_3-1-2021_11-12-59_OS_sn1255_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_744_Angio (6mmx6mm)_11-29-2019_10-8-4_OD_sn0976_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_744_Angio (6mmx6mm)_11-29-2019_10-14-38_OS_sn0982_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_741_Angio (6mmx6mm)_11-12-2019_9-29-9_OS_sn0961_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_741_Angio (6mmx6mm)_11-12-2019_9-24-35_OD_sn0956_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_738_Angio (6mmx6mm)_3-22-2021_14-50-1_OS_sn1246_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_738_Angio (6mmx6mm)_3-22-2021_14-46-43_OD_sn1243_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_738_Angio (6mmx6mm)_11-8-2019_9-18-22_OD_sn0941_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_735_Angio (6mmx6mm)_10-18-2019_10-47-58_OS_sn0925_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_735_Angio (6mmx6mm)_10-18-2019_10-42-45_OD_sn0920_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_726_Angio (6mmx6mm)_11-3-2020_13-35-6_OS_sn1102_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_726_Angio (6mmx6mm)_11-3-2020_13-28-16_OD_sn1098_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_724_Angio (6mmx6mm)_9-16-2019_10-41-18_OS_sn0905_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_722_Angio (6mmx6mm)_3-23-2022_10-53-37_OS_sn1845_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_722_Angio (6mmx6mm)_3-23-2022_10-45-0_OD_sn1840_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_720_Angio (6mmx6mm)_9-2-2019_10-30-6_OS_sn0892_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_720_Angio (6mmx6mm)_9-2-2019_10-27-39_OD_sn0890_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_719_Angio (6mmx6mm)_9-23-2020_12-17-54_OS_sn1056_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_719_Angio (6mmx6mm)_9-23-2020_12-12-52_OD_sn1053_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_716_Angio (6mmx6mm)_7-3-2019_10-27-6_OS_sn0837_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_716_Angio (6mmx6mm)_7-3-2019_10-17-22_OD_sn0830_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_714_Angio (6mmx6mm)_6-7-2019_12-9-47_OD_sn0804_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_711_Angio (6mmx6mm)_3-2-2022_10-26-52_OS_sn1814_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_711_Angio (6mmx6mm)_3-2-2022_10-23-35_OD_sn1810_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_710_Angio (6mmx6mm)_5-28-2019_10-4-3_OD_sn0795_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_705_Angio (6mmx6mm)_3-4-2022_14-10-12_OS_sn1822_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_703_Angio (6mmx6mm)_9-8-2021_9-27-36_OS_sn1471_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_703_Angio (6mmx6mm)_9-8-2021_9-23-11_OD_sn1467_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_703_Angio (6mmx6mm)_5-6-2019_10-4-22_OD_sn0783_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_703_Angio (6mmx6mm)_5-6-2019_10-12-18_OS_sn0788_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_699_Angio (6mmx6mm)_4-23-2019_11-0-15_OS_sn0778_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_699_Angio (6mmx6mm)_4-23-2019_10-52-47_OD_sn0774_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_696_Angio (6mmx6mm)_4-18-2019_10-42-14_OS_sn0769_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_693_Angio (6mmx6mm)_4-9-2019_11-39-54_OS_sn0760_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_693_Angio (6mmx6mm)_4-9-2019_11-28-59_OD_sn0753_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_692_Angio (6mmx6mm)_12-29-2021_11-37-17_OS_sn1730_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_692_Angio (6mmx6mm)_12-29-2021_11-36-14_OD_sn1729_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_691_Angio (6mmx6mm)_4-9-2019_10-7-20_OS_sn0743_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_691_Angio (6mmx6mm)_4-9-2019_10-1-56_OD_sn0737_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_685_Angio (6mmx6mm)_3-21-2019_11-36-22_OS_sn0721_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_685_Angio (6mmx6mm)_3-21-2019_11-31-45_OD_sn0716_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_682_Angio (6mmx6mm)_3-1-2019_10-28-30_OS_sn0700_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_682_Angio (6mmx6mm)_3-1-2019_10-23-34_OD_sn0695_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_679_Angio (6mmx6mm)_3-21-2019_10-35-56_OS_sn0710_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_678_Angio (6mmx6mm)_2-28-2019_10-13-24_OS_sn0689_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_678_Angio (6mmx6mm)_2-28-2019_10-11-20_OD_sn0687_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_673_Angio (6mmx6mm)_1-21-2019_10-7-54_OD_sn0663_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_670_Angio (6mmx6mm)_1-21-2019_11-2-37_OS_sn0672_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_670_Angio (6mmx6mm)_1-21-2019_10-57-27_OD_sn0668_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_660_Angio (6mmx6mm)_12-11-2020_11-3-50_OS_sn1154_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_660_Angio (6mmx6mm)_12-11-2020_10-56-51_OD_sn1148_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_659_Angio (6mmx6mm)_1-7-2019_11-9-54_OS_sn0627_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_659_Angio (6mmx6mm)_1-7-2019_11-2-29_OD_sn0620_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_657_Angio (6mmx6mm)_12-28-2018_10-5-20_OD_sn0578_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_657_Angio (6mmx6mm)_12-28-2018_10-18-3_OS_sn0585_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_653_Angio (6mmx6mm)_12-31-2018_9-51-52_OS_sn0612_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_653_Angio (6mmx6mm)_12-31-2018_9-46-14_OD_sn0607_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_652_Angio (6mmx6mm)_12-31-2018_9-43-9_OS_sn0605_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_652_Angio (6mmx6mm)_12-31-2018_9-37-14_OD_sn0600_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_648_Angio (6mmx6mm)_12-28-2018_11-0-40_OS_sn0593_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_648_Angio (6mmx6mm)_12-28-2018_10-49-35_OD_sn0587_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_646_Angio (6mmx6mm)_12-27-2018_10-45-33_OS_sn0567_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_646_Angio (6mmx6mm)_12-27-2018_10-37-51_OD_sn0562_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_645_Angio (6mmx6mm)_12-14-2018_10-51-7_OS_sn0555_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_645_Angio (6mmx6mm)_12-14-2018_10-45-7_OD_sn0551_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_644_Angio (6mmx6mm)_12-6-2018_14-37-4_OS_sn0534_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_644_Angio (6mmx6mm)_12-6-2018_14-30-50_OD_sn0529_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_638_Angio (6mmx6mm)_12-24-2020_11-0-59_OS_sn1178_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_638_Angio (6mmx6mm)_12-24-2020_10-57-16_OD_sn1175_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_637_Angio (6mmx6mm)_12-14-2018_11-5-13_OD_sn0541_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_637_Angio (6mmx6mm)_12-14-2018_11-13-17_OS_sn0544_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_636_Angio (6mmx6mm)_12-27-2018_12-0-35_OS_sn0575_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_636_Angio (6mmx6mm)_12-27-2018_11-53-34_OD_sn0571_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_635_Angio (6mmx6mm)_11-30-2018_11-26-6_OS_sn0506_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_635_Angio (6mmx6mm)_11-30-2018_11-20-1_OD_sn0501_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_631_Angio (6mmx6mm)_12-5-2018_14-32-22_OS_sn0516_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_631_Angio (6mmx6mm)_12-5-2018_14-25-12_OD_sn0511_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_629_Angio (6mmx6mm)_11-29-2018_10-39-5_OS_sn0496_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_629_Angio (6mmx6mm)_11-29-2018_10-31-28_OD_sn0490_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_624_Angio (6mmx6mm)_11-19-2018_9-48-56_OS_sn0468_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_624_Angio (6mmx6mm)_11-19-2018_9-41-36_OD_sn0461_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_622_Angio (6mmx6mm)_11-16-2018_9-56-5_OS_sn0459_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_622_Angio (6mmx6mm)_11-16-2018_9-50-34_OD_sn0455_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_619_Angio (6mmx6mm)_11-1-2018_13-58-10_OS_sn0441_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_619_Angio (6mmx6mm)_11-1-2018_13-52-21_OD_sn0436_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_616_Angio (6mmx6mm)_3-8-2021_12-9-22_OS_sn1239_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_616_Angio (6mmx6mm)_3-8-2021_11-56-42_OD_sn1234_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_616_Angio (6mmx6mm)_10-29-2018_11-21-5_OS_sn0425_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_616_Angio (6mmx6mm)_10-29-2018_11-14-52_OD_sn0420_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_612_Angio (6mmx6mm)_11-1-2018_10-47-19_OS_sn0433_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_612_Angio (6mmx6mm)_11-1-2018_10-41-21_OD_sn0430_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_606_Angio (6mmx6mm)_10-25-2018_10-44-32_OS_sn0417_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_606_Angio (6mmx6mm)_10-25-2018_10-39-35_OD_sn0412_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_601_Angio (6mmx6mm)_10-25-2018_10-26-19_OS_sn0410_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_601_Angio (6mmx6mm)_10-25-2018_10-21-15_OD_sn0405_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_597_Angio (6mmx6mm)_10-15-2018_11-0-10_OS_sn0400_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_597_Angio (6mmx6mm)_10-15-2018_10-55-6_OD_sn0395_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_593_Angio (6mmx6mm)_10-1-2018_11-29-11_OS_sn0381_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_593_Angio (6mmx6mm)_10-1-2018_11-26-16_OD_sn0378_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_591_Angio (6mmx6mm)_9-17-2018_12-30-37_OS_sn0366_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_591_Angio (6mmx6mm)_9-17-2018_12-27-52_OD_sn0363_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_588_Angio (6mmx6mm)_9-17-2018_10-16-19_OS_sn0358_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_588_Angio (6mmx6mm)_9-17-2018_10-11-32_OD_sn0354_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_584_Angio (6mmx6mm)_10-15-2018_10-16-51_OS_sn0392_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_584_Angio (6mmx6mm)_10-15-2018_10-10-40_OD_sn0385_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_583_Angio (6mmx6mm)_9-17-2018_12-48-23_OS_sn0374_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_583_Angio (6mmx6mm)_9-17-2018_12-42-54_OD_sn0370_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_582_Angio (6mmx6mm)_9-13-2018_9-41-48_OS_sn0341_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_582_Angio (6mmx6mm)_9-13-2018_9-40-43_OD_sn0340_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_578_Angio (6mmx6mm)_9-6-2018_10-32-34_OS_sn0311_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_578_Angio (6mmx6mm)_9-6-2018_10-28-17_OD_sn0307_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_577_Angio (6mmx6mm)_9-3-2018_10-6-38_OS_sn0299_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_577_Angio (6mmx6mm)_9-3-2018_10-5-31_OD_sn0298_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_576_Angio (6mmx6mm)_9-10-2018_11-44-24_OD_sn0336_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_576_Angio (6mmx6mm)_9-10-2018_11-43-17_OS_sn0335_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_575_Angio (6mmx6mm)_9-10-2018_10-46-48_OS_sn0329_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_575_Angio (6mmx6mm)_9-10-2018_10-40-50_OD_sn0323_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_573_Angio (6mmx6mm)_9-6-2018_11-8-44_OS_sn0320_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_567_Angio (6mmx6mm)_8-30-2018_10-58-41_OS_sn0295_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_567_Angio (6mmx6mm)_8-30-2018_10-54-20_OD_sn0291_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_562_Angio (6mmx6mm)_9-15-2020_13-59-50_OS_sn1014_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_562_Angio (6mmx6mm)_9-15-2020_13-53-8_OD_sn1009_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_562_Angio (6mmx6mm)_8-30-2018_10-39-53_OS_sn0287_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_562_Angio (6mmx6mm)_8-30-2018_10-36-4_OD_sn0284_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_560_Angio (6mmx6mm)_8-16-2018_11-31-10_OS_sn0278_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_555_Angio (6mmx6mm)_7-27-2018_11-28-33_OS_sn0256_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_555_Angio (6mmx6mm)_7-27-2018_11-25-40_OD_sn0253_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_553_Angio (6mmx6mm)_12-10-2020_11-33-15_OS_sn1143_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_553_Angio (6mmx6mm)_7-26-2018_10-9-2_OS_sn0230_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_553_Angio (6mmx6mm)_7-26-2018_10-1-11_OD_sn0222_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_552_Angio (6mmx6mm)_7-26-2018_11-1-30_OS_sn0239_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_552_Angio (6mmx6mm)_7-26-2018_10-55-37_OD_sn0235_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_548_Angio (6mmx6mm)_11-10-2021_10-9-58_OD_sn1644_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_548_Angio (6mmx6mm)_11-10-2021_10-11-3_OS_sn1645_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_546_Angio (6mmx6mm)_8-7-2018_11-9-22_OS_sn0269_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_546_Angio (6mmx6mm)_8-7-2018_11-6-55_OD_sn0268_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_544_Angio (6mmx6mm)_7-13-2018_11-31-31_OS_sn0202_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_544_Angio (6mmx6mm)_7-13-2018_11-26-7_OD_sn0197_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_541_Angio (6mmx6mm)_7-27-2018_10-31-36_OS_sn0248_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_540_Angio (6mmx6mm)_7-9-2018_12-15-11_OS_sn0193_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_537_Angio (6mmx6mm)_7-9-2018_9-38-29_OS_sn0169_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_537_Angio (6mmx6mm)_7-9-2018_9-34-34_OD_sn0166_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_535_Angio (6mmx6mm)_7-23-2018_12-12-26_OS_sn0218_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_526_Angio (6mmx6mm)_7-30-2018_10-28-48_OS_sn0264_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_526_Angio (6mmx6mm)_7-30-2018_10-25-9_OD_sn0260_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_523_Angio (6mmx6mm)_6-25-2018_10-56-43_OS_sn0155_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_523_Angio (6mmx6mm)_6-25-2018_10-50-51_OD_sn0151_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_521_Angio (6mmx6mm)_3-2-2021_9-31-48_OS_sn1263_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_521_Angio (6mmx6mm)_3-2-2021_9-28-6_OD_sn1259_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_519_Angio (6mmx6mm)_7-9-2018_10-33-5_OS_sn0178_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_519_Angio (6mmx6mm)_7-9-2018_10-29-31_OD_sn0174_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_515_Angio (6mmx6mm)_7-9-2018_12-35-16_OS_sn2685_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_515_Angio (6mmx6mm)_7-9-2018_12-29-15_OD_sn2681_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_511_Angio (6mmx6mm)_6-29-2018_11-40-4_OS_sn0161_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_510_Angio (6mmx6mm)_6-25-2018_10-23-17_OS_sn0146_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_510_Angio (6mmx6mm)_6-25-2018_10-18-58_OD_sn0142_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_509_Angio (6mmx6mm)_6-22-2018_9-59-52_OS_sn0126_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_509_Angio (6mmx6mm)_6-22-2018_9-48-56_OD_sn0123_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_507_Angio (6mmx6mm)_6-22-2018_10-35-2_OS_sn0137_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_507_Angio (6mmx6mm)_6-22-2018_10-28-59_OD_sn0133_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_506_Angio (6mmx6mm)_10-14-2020_14-34-21_OS_sn1084_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_506_Angio (6mmx6mm)_10-14-2020_14-31-2_OD_sn1080_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_503_Angio (6mmx6mm)_6-14-2018_9-44-40_OS_sn0113_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_503_Angio (6mmx6mm)_6-14-2018_9-40-50_OD_sn0109_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_493_Angio (6mmx6mm)_10-8-2020_14-9-0_OD_sn1072_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_493_Angio (6mmx6mm)_10-8-2020_14-12-13_OS_sn1076_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_470_Angio (6mmx6mm)_9-4-2019_9-56-59_OS_sn0882_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_470_Angio (6mmx6mm)_9-4-2019_9-52-9_OD_sn0878_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_399_Angio (6mmx6mm)_6-26-2019_9-46-3_OS_sn0823_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_399_Angio (6mmx6mm)_6-26-2019_9-33-17_OD_sn0821_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_368_Angio (6mmx6mm)_9-24-2019_10-43-53_OS_sn0872_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_368_Angio (6mmx6mm)_9-24-2019_10-35-33_OD_sn0866_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_357_Angio (6mmx6mm)_8-7-2020_9-54-59_OD_sn1026_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_357_Angio (6mmx6mm)_8-7-2020_10-0-31_OS_sn1031_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_353_Angio (6mmx6mm)_10-27-2021_12-29-4_OS_sn1567_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_353_Angio (6mmx6mm)_10-27-2021_12-27-40_OD_sn1566_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_330_Angio (6mmx6mm)_1-20-2021_10-35-0_OS_sn1197_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_330_Angio (6mmx6mm)_1-20-2021_10-30-38_OD_sn1193_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_326_Angio (6mmx6mm)_1-27-2022_17-6-15_OS_sn1748_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_293_Angio (6mmx6mm)_11-22-2021_14-7-40_OS_sn1683_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_293_Angio (6mmx6mm)_11-22-2021_14-2-15_OD_sn1681_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_279_Angio (6mmx6mm)_12-6-2019_14-51-28_OS_sn24149_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_279_Angio (6mmx6mm)_12-6-2019_14-47-21_OD_sn24145_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_278_Angio (6mmx6mm)_10-24-2019_10-56-58_OS_sn0935_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_278_Angio (6mmx6mm)_10-24-2019_10-54-31_OD_sn0933_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_276_Angio (6mmx6mm)_10-27-2021_14-23-22_OS_sn1576_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_276_Angio (6mmx6mm)_10-27-2021_14-22-5_OD_sn1575_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_266_Angio (6mmx6mm)_11-1-2021_9-57-11_OS_sn1621_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_266_Angio (6mmx6mm)_11-1-2021_9-51-17_OD_sn1615_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_240_Angio (6mmx6mm)_11-18-2019_9-59-48_OD_sn0966_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_240_Angio (6mmx6mm)_11-18-2019_10-9-20_OS_sn0972_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_238_Angio (6mmx6mm)_9-27-2019_14-52-40_OS_sn0861_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_238_Angio (6mmx6mm)_9-27-2019_14-50-19_OD_sn0859_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_225_Angio (6mmx6mm)_10-14-2019_11-18-35_OS_sn0913_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_225_Angio (6mmx6mm)_10-14-2019_11-14-41_OD_sn0909_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_188_Angio (6mmx6mm)_9-29-2021_10-12-45_OD_sn1475_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_128_Angio (6mmx6mm)_9-24-2019_9-27-15_OS_sn0850_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_128_Angio (6mmx6mm)_9-24-2019_9-21-26_OD_sn0845_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_124_Angio (6mmx6mm)_6-24-2019_10-9-39_OD_sn0810_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_124_Angio (6mmx6mm)_6-24-2019_10-18-57_OS_sn0816_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_081_Angio (6mmx6mm)_1-25-2019_11-8-35_OD_sn0677_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_081_Angio (6mmx6mm)_1-25-2019_11-10-0_OS_sn0678_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_071_Angio (6mmx6mm)_1-11-2019_10-50-31_OS_sn0659_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_071_Angio (6mmx6mm)_1-11-2019_10-42-6_OD_sn0653_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_029_Angio (6mmx6mm)_10-12-2021_15-29-4_OS_sn1524_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_029_Angio (6mmx6mm)_10-12-2021_15-11-28_OD_sn1514_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_017_Angio (6mmx6mm)_12-6-2018_10-34-3_OS_sn0527_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_017_Angio (6mmx6mm)_12-6-2018_10-21-27_OD_sn0518_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_012_Angio (6mmx6mm)_1-10-2019_11-46-40_OS_sn0649_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_011_Angio (6mmx6mm)_3-5-2021_14-49-4_OS_sn1270_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_011_Angio (6mmx6mm)_3-5-2021_14-46-29_OD_sn1267_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_008_Angio (6mmx6mm)_11-19-2018_10-26-1_OS_sn0473_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_005_Angio (6mmx6mm)_4-8-2019_11-28-3_OS_sn0734_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_005_Angio (6mmx6mm)_4-8-2019_11-22-5_OD_sn0727_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_003_Angio (6mmx6mm)_12-24-2019_10-36-50_OS_sn1002_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREMODEL_HTN_003_Angio (6mmx6mm)_12-24-2019_10-31-32_OD_sn0997_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7618_Angio (6mmx6mm)_9-27-2021_16-4-37_OS_sn3716_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7586_Angio (6mmx6mm)_9-6-2021_16-57-28_OD_sn3701_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7454_Angio (6mmx6mm)_9-3-2021_16-13-37_OD_sn3696_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7429-C_Angio (6mmx6mm)_2-25-2021_11-53-26_OS_sn3170_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7343-S_Angio (6mmx6mm)_2-25-2021_15-2-14_OS_sn3179_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7337_Angio (6mmx6mm)_2-4-2021_16-33-28_OS_sn3102_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7330-S_Angio (6mmx6mm)_1-28-2021_11-38-36_OD_sn2868_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7330_Angio (6mmx6mm)_1-28-2021_11-55-48_OD_sn2873_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS7264-C_Angio (6mmx6mm)_4-16-2021_11-20-25_OD_sn3257_cube_z.tif
# ...
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2344_Angio (6mmx6mm)_9-6-2018_11-48-56_OS_sn1039_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2344_Angio (6mmx6mm)_9-6-2018_11-44-45_OD_sn1035_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2325-C_Angio (6mmx6mm)_5-10-2021_15-56-30_OS_sn3345_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2315_Angio (6mmx6mm)_6-12-2018_16-4-1_OS_sn0680_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2315_Angio (6mmx6mm)_6-12-2018_16-0-25_OD_sn0676_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2265_Angio (6mmx6mm)_6-17-2019_12-20-57_OD_sn1346_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2244_Angio (6mmx6mm)_6-25-2019_12-25-28_OS_sn1361_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2213_Angio (6mmx6mm)_8-10-2018_16-23-42_OD_sn0977_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2213_Angio (6mmx6mm)_8-10-2018_16-17-56_OS_sn0974_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2165_Angio (6mmx6mm)_8-23-2018_16-43-8_OD_sn1008_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2130-S_Angio (6mmx6mm)_8-6-2019_13-32-58_OD_sn1467_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2113-C_Angio (6mmx6mm)_7-7-2021_11-31-58_OS_sn3451_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2096-C_Angio (6mmx6mm)_4-26-2021_10-33-8_OD_sn3308_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2095_Angio (6mmx6mm)_6-21-2019_12-15-36_OD_sn1357_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2084-S_Angio (6mmx6mm)_8-20-2021_15-49-58_OS_sn3637_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2002_Angio (6mmx6mm)_6-29-2018_11-27-37_OD_sn0754_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS2002_Angio (6mmx6mm)_6-29-2018_11-18-18_OS_sn0748_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1999-C_Angio (6mmx6mm)_7-30-2020_12-2-29_OD_sn2352_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1994_Angio (6mmx6mm)_3-10-2021_10-39-28_OS_sn2934_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1989_Angio (6mmx6mm)_2-19-2021_15-53-0_OD_sn3148_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1944_Angio (6mmx6mm)_2-17-2021_16-13-17_OS_sn3138_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1941_Angio (6mmx6mm)_12-3-2019_11-30-55_OD_sn1982_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1923-S_Angio (6mmx6mm)_9-24-2019_12-32-30_OD_sn1619_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1909_Angio (6mmx6mm)_12-3-2019_15-45-21_OD_sn1989_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1875_Angio (6mmx6mm)_7-8-2019_13-23-12_OD_sn1403_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1851_Angio (6mmx6mm)_4-28-2021_10-8-56_OD_sn3313_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1849-S_Angio (6mmx6mm)_12-23-2019_16-54-50_OS_sn2082_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1845_Angio (6mmx6mm)_7-18-2019_12-53-9_OD_sn1422_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1840_Angio (6mmx6mm)_12-20-2019_16-13-31_OS_sn2077_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1834_Angio (6mmx6mm)_6-11-2019_15-31-6_OD_sn1329_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1832_Angio (6mmx6mm)_9-19-2019_12-5-37_OS_sn1592_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1781-C_Angio (6mmx6mm)_2-8-2021_16-25-22_OS_sn3110_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1761_Angio (6mmx6mm)_6-7-2019_12-35-56_OD_sn1306_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1753_Angio (6mmx6mm)_6-10-2019_12-25-23_OD_sn1318_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1738_Angio (6mmx6mm)_7-23-2019_12-16-41_OS_sn1446_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1729-S_Angio (6mmx6mm)_7-16-2019_12-51-57_OD_sn1418_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1727-S_Angio (6mmx6mm)_8-16-2019_17-0-36_OD_sn1489_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1727_Angio (6mmx6mm)_8-16-2019_17-18-12_OD_sn1495_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1689-S_Angio (6mmx6mm)_7-21-2020_10-56-21_OD_sn2295_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1689_Angio (6mmx6mm)_7-21-2020_11-15-37_OD_sn2302_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1685-S_Angio (6mmx6mm)_7-1-2019_12-26-56_OD_sn1370_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1662-C_Angio (6mmx6mm)_6-2-2021_16-35-4_OD_sn3366_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1657_Angio (6mmx6mm)_7-15-2019_16-52-59_OS_sn1409_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1650_Angio (6mmx6mm)_5-28-2019_16-25-8_OD_sn1270_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1609_Angio (6mmx6mm)_8-17-2019_12-24-35_OD_sn1502_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1606_Angio (6mmx6mm)_8-20-2019_13-41-36_OS_sn1521_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1559_Angio (6mmx6mm)_6-14-2019_12-9-13_OS_sn1336_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1539_Angio (6mmx6mm)_7-8-2019_13-1-44_OD_sn1399_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1523-S_Angio (6mmx6mm)_3-31-2021_11-57-12_OS_sn3066_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1523_Angio (6mmx6mm)_3-31-2021_11-36-43_OD_sn3072_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1512-C_Angio (6mmx6mm)_7-29-2021_15-49-54_OS_sn3515_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1489_Angio (6mmx6mm)_8-10-2018_11-30-49_OD_sn0953_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1489_Angio (6mmx6mm)_8-10-2018_11-22-25_OS_sn0947_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1484-C_Angio (6mmx6mm)_7-23-2020_11-57-4_OS_sn2328_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1433-S_Angio (6mmx6mm)_8-23-2021_11-30-31_OD_sn3642_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1419_Angio (6mmx6mm)_5-30-2019_12-0-24_OS_sn1277_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1316_Angio (6mmx6mm)_6-14-2018_11-6-20_OS_sn0695_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1316_Angio (6mmx6mm)_6-14-2018_11-0-52_OD_sn0691_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1311_Angio (6mmx6mm)_4-1-2019_13-1-10_OS_sn1180_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1307-C_Angio (6mmx6mm)_8-2-2021_15-33-10_OD_sn3530_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1233_Angio (6mmx6mm)_6-14-2019_12-32-24_OD_sn1341_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1145_Angio (6mmx6mm)_9-6-2018_16-39-2_OS_sn1046_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1050_Angio (6mmx6mm)_4-11-2019_12-57-14_OS_sn1206_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS1004-S_Angio (6mmx6mm)_5-14-2019_12-32-50_OS_sn1243_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0984-S_Angio (6mmx6mm)_12-6-2019_15-38-57_OS_sn2015_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0981-C_Angio (6mmx6mm)_4-29-2021_11-18-44_OS_sn3318_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0981_Angio (6mmx6mm)_11-22-2019_12-36-48_OS_sn1921_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0967-S_Angio (6mmx6mm)_1-21-2020_16-3-5_OD_sn0136_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0967_Angio (6mmx6mm)_1-21-2020_15-55-56_OD_sn0132_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0963_Angio (6mmx6mm)_12-27-2019_16-31-57_OS_sn2116_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0954-S_Angio (6mmx6mm)_11-29-2019_16-30-43_OS_sn1961_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0949_Angio (6mmx6mm)_12-26-2019_15-25-49_OS_sn2100_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0948_Angio (6mmx6mm)_11-27-2020_16-26-0_OD_sn36924_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0941-S_Angio (6mmx6mm)_2-18-2021_11-57-43_OD_sn3141_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0932_Angio (6mmx6mm)_11-12-2020_17-1-53_OS_sn2597_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0923_Angio (6mmx6mm)_11-11-2019_16-2-54_OS_sn1869_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0891_Angio (6mmx6mm)_12-9-2019_12-32-17_OS_sn2029_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0885_Angio (6mmx6mm)_12-20-2019_11-45-20_OS_sn2074_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0885_Angio (6mmx6mm)_12-20-2019_11-40-50_OD_sn2072_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0884-S_Angio (6mmx6mm)_12-16-2019_11-55-23_OD_sn2042_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0865_Angio (6mmx6mm)_12-27-2019_12-25-54_OD_sn2112_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0862_Angio (6mmx6mm)_7-23-2020_11-37-31_OS_sn2323_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0857_Angio (6mmx6mm)_11-18-2019_11-31-15_OS_sn1899_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0847_Angio (6mmx6mm)_4-14-2021_15-20-27_OD_sn3250_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0777-C_Angio (6mmx6mm)_10-5-2020_12-40-34_OS_sn2452_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0660_Angio (6mmx6mm)_8-3-2020_16-14-16_OD_sn30118_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0466_Angio (6mmx6mm)_1-14-2020_16-15-21_OS_sn0091_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0398-C_Angio (6mmx6mm)_7-17-2020_11-26-53_OS_sn2286_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0379-C_Angio (6mmx6mm)_7-24-2020_11-24-35_OS_sn2339_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0377-S_Angio (6mmx6mm)_2-3-2020_11-50-4_OD_sn0167_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0369-S_Angio (6mmx6mm)_1-17-2020_16-15-39_OD_sn0113_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0349-C_Angio (6mmx6mm)_8-27-2020_16-54-28_OD_sn2420_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0316_Angio (6mmx6mm)_2-4-2020_11-10-17_OS_sn0175_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0307-C_Angio (6mmx6mm)_7-14-2020_11-10-15_OD_sn2257_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0236-C_Angio (6mmx6mm)_3-25-2021_16-43-30_OD_sn3039_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0229_Angio (6mmx6mm)_4-9-2021_10-27-57_OD_sn3227_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0219-S_Angio (6mmx6mm)_8-23-2021_16-0-42_OS_sn3647_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0208-C_Angio (6mmx6mm)_9-11-2020_15-47-47_OS_sn2200_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0193_Angio (6mmx6mm)_12-19-2019_15-26-16_OD_sn2067_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0186-S_Angio (6mmx6mm)_8-19-2021_15-46-47_OD_sn3622_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0116-S_Angio (6mmx6mm)_8-19-2021_15-24-49_OS_sn3619_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0051-S_Angio (6mmx6mm)_8-16-2021_16-4-7_OD_sn3583_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0048-S_Angio (6mmx6mm)_8-19-2021_11-27-54_OS_sn3610_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0032-C_Angio (6mmx6mm)_7-28-2021_15-21-26_OD_sn3508_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS0015_Angio (6mmx6mm)_6-17-2021_15-53-38_OD_sn3401_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS5998-S_Angio (6mmx6mm)_3-18-2021_10-10-26_OD_sn2986_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PR1406_PS3679-C_Angio (6mmx6mm)_6-16-2021_16-2-21_OD_sn3395_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PE_GLAU0199_Angio (6mmx6mm)_6-10-2021_12-59-34_OS_sn1379_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PE_GLAU0199_Angio (6mmx6mm)_6-10-2021_12-51-6_OD_sn1373_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREVERSE_HTN_0053_Angio (6mmx6mm)_1-11-2022_16-9-28_OD_sn57693_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
# E:/enface_plex\PREVERSE_HTN_0053_Angio (6mmx6mm)_1-11-2022_16-16-55_OS_sn57698_cube_z.tif
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
