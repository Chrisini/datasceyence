# %% [markdown]
# # MUNIT

# %% [markdown]
# # Train

# %%
"""
Copyright (C) 2018 NVIDIA Corporation.  All rights reserved.
Licensed under the CC BY-NC-SA 4.0 license (https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode).
"""

# vgg_preprocess needs a device

import os
import sys
import shutil

from munit.trainer import MUNIT_Trainer, UNIT_Trainer
from munit.utils import get_all_data_loaders, prepare_sub_folder, write_html, write_loss, get_config, write_2images, Timer

import torch
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

import tensorboardX

config_file = 'munit/configs/img2img_folder.yaml'
output_path = 'munit/results'
trainer = "MUNIT" # or UNIT

device = "cpu"

# Load experiment setting
config = get_config(config_file)
max_iter = config['max_iter']
display_size = config['display_size']
config['vgg_model_path'] = output_path

# Setup model and data loader
if trainer == 'MUNIT':
    trainer = MUNIT_Trainer(config)
elif trainer == 'UNIT':
    trainer = UNIT_Trainer(config)
else:
    sys.exit("Only support MUNIT|UNIT")
trainer.to(device)
train_loader_a, train_loader_b, test_loader_a, test_loader_b = get_all_data_loaders(config)
train_display_images_a = torch.stack([train_loader_a.dataset[i] for i in range(display_size)]).to(device)
train_display_images_b = torch.stack([train_loader_b.dataset[i] for i in range(display_size)]).to(device)
test_display_images_a = torch.stack([test_loader_a.dataset[i] for i in range(display_size)]).to(device)
test_display_images_b = torch.stack([test_loader_b.dataset[i] for i in range(display_size)]).to(device)

# Setup logger and output folders
model_name = os.path.splitext(os.path.basename(config_file))[0]
train_writer = tensorboardX.SummaryWriter(os.path.join(output_path + "/logs", model_name))
output_directory = os.path.join(output_path + "/outputs", model_name)
checkpoint_directory, image_directory = prepare_sub_folder(output_directory)
shutil.copy(config_file, os.path.join(output_directory, 'config.yaml')) # copy config file to output folder

# Start training
# iterations = trainer.resume(checkpoint_directory, hyperparameters=config) if resume else 0

for iterations in range(1, max_iter+1):
    for it, (images_a, images_b) in enumerate(zip(train_loader_a, train_loader_b)):
        
        
        images_a, images_b = images_a.to(device).detach(), images_b.to(device).detach()

        with Timer("Elapsed time in update: %f"):
            # Main training code
            trainer.dis_update(images_a, images_b, config)
            trainer.gen_update(images_a, images_b, config)
            torch.cuda.synchronize()
            
        trainer.update_learning_rate()

        # log stuff
        if (iterations) % config['image_save_iter'] == 0:
            
            print("Iteration: %08d/%08d" % (iterations, max_iter))
            write_loss(iterations, trainer, train_writer)
            
            # Write images
            with torch.no_grad():
                test_image_outputs = trainer.sample(test_display_images_a, test_display_images_b)
                train_image_outputs = trainer.sample(train_display_images_a, train_display_images_b)
            write_2images(test_image_outputs, display_size, image_directory, 'test_%08d' % (iterations + 1))
            write_2images(train_image_outputs, display_size, image_directory, 'train_%08d' % (iterations + 1))
            # HTML
            write_html(output_directory + "/index.html", iterations + 1, config['image_save_iter'], 'images')

            # save images
            with torch.no_grad():
                image_outputs = trainer.sample(train_display_images_a, train_display_images_b)
            write_2images(image_outputs, display_size, image_directory, 'train_current')

            # Save network weights
            trainer.save(checkpoint_directory, iterations)
# Out:
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0DB0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA3D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA5180>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA04F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB2B80>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB3A90>
# Elapsed time in update: 8.628567
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23F90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F29EA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2A040>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F29450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F313B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F322C0>
# Elapsed time in update: 7.002807
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F291D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DF90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F29A40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F313B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2B090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2B630>
# Elapsed time in update: 7.787127
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F30E50>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEF0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C180>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34360>
# Elapsed time in update: 7.458171
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F35720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB3C70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DD10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33220>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F38360>
# Elapsed time in update: 7.144671
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D680>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F35C70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE4F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F35D60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E180>
# Elapsed time in update: 7.196696
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F35BD0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F35090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DF40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39EA0>
# Elapsed time in update: 8.807365
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33B80>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE9F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D8B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E360>
# Elapsed time in update: 7.359632
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DF90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34540>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D3B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F333B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F360>
# Elapsed time in update: 7.247047
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D9A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F349A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F38D60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34A40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F354A0>
# Elapsed time in update: 7.174364
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34C70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D1D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB4400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F38810>
# Elapsed time in update: 6.939919
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DE00>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C1D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2CE00>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F236D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F325E0>
# Elapsed time in update: 7.100981
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2CB30>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DB80>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D0E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33CC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C6D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F345E0>
# Elapsed time in update: 7.475819
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEF0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F339A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2FD60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DD10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3E810>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E680>
# Elapsed time in update: 8.412687
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33B80>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DD60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23310>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3E310>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D1D0>
# Elapsed time in update: 7.605209
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F393B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F236D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DBD0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F323B0>
# Elapsed time in update: 6.933566
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23C70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2FE00>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0AE0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F238B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39220>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F334F0>
# Elapsed time in update: 7.053548
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F341D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23A40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAC400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F364F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F4F0>
# Elapsed time in update: 6.964139
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D2C0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA4CC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAC3B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32540>
# Elapsed time in update: 6.735649
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34C20>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33680>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3CCC0>
# Elapsed time in update: 6.817737
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D6D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34040>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAC3B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33770>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36680>
# Elapsed time in update: 6.781911
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34A40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F343B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D4A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F397C0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3BCC0>
# Elapsed time in update: 6.848712
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32680>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3C770>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F372C0>
# Elapsed time in update: 7.112027
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F329A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA63B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2FD60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B400>
# Elapsed time in update: 6.988865
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34810>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D3B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39BD0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F37040>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E400>
# Elapsed time in update: 6.868721
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DBD0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34540>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB01D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAC360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F37630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32130>
# Elapsed time in update: 7.245767
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34270>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D0E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F346D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F37630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3F360>
# Elapsed time in update: 6.975524
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D540>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB0720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23770>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B680>
# Elapsed time in update: 6.917169
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34D60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB0680>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3C630>
# Elapsed time in update: 6.855428
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34180>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB0720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D8B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39770>
# Elapsed time in update: 6.771899
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F33D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAC450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3CCC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3F360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D270>
# Elapsed time in update: 7.036179
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23E00>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F343B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B2C0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F334A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F363B0>
# Elapsed time in update: 6.907534
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C5E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34A90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DF90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE680>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B3B0>
# Elapsed time in update: 6.744545
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34B30>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2CEA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB04A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34AE0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F335E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F394F0>
# Elapsed time in update: 6.949989
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D5E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2CBD0>
# Elapsed time in update: 6.952893
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34C70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE9F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F37720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2EB30>
# Elapsed time in update: 6.853680
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34180>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DE00>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEF0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F23720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32630>
# Elapsed time in update: 7.682712
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34CC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D0E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DB30>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA8720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F399A0>
# Elapsed time in update: 7.818125
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34040>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F349A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F37360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36770>
# Elapsed time in update: 6.964895
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DC70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA8950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34A90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F374A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C3B0>
# Elapsed time in update: 6.934964
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34B80>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34CC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E4A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F393B0>
# Elapsed time in update: 6.930000
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F41220>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB0590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F41A90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E5E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F364F0>
# Elapsed time in update: 6.863672
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F342C0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DD60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34680>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F5E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F41F90>
# Elapsed time in update: 6.952922
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34CC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0AE0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB2BD0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F37C70>
# Elapsed time in update: 6.918553
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F343B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D4A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB05E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E630>
# Elapsed time in update: 7.140278
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34AE0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DC70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D680>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32860>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C770>
# Elapsed time in update: 7.075633
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34F40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB2F40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36270>
# Elapsed time in update: 7.225683
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34040>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DC20>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F37270>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB4400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C220>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F323B0>
# Elapsed time in update: 7.563320
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB3BD0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3DE50>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F063AE00>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F366D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F3B0>
# Elapsed time in update: 7.469050
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3BE00>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB3D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F344F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C9A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F364F0>
# Elapsed time in update: 6.878531
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34C20>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DE50>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34220>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D5E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3CB30>
# Elapsed time in update: 6.884713
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D040>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34EF0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32630>
# Elapsed time in update: 6.976450
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34770>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D180>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0A40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB3310>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C630>
# Elapsed time in update: 6.980393
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34EA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D180>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39D60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F42770>
# Elapsed time in update: 7.303523
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D3B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F324A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3C360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F42D10>
# Elapsed time in update: 8.343211
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D7C0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36B80>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F349A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F404A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F323B0>
# Elapsed time in update: 9.300324
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39770>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F395E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B4A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F42090>
# Elapsed time in update: 10.817199
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F39F90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34C20>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB05E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DF90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F325E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32630>
# Elapsed time in update: 9.789910
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34DB0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB3310>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA0AE0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F325E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E4F0>
# Elapsed time in update: 8.855020
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB05E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D220>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F42720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B540>
# Elapsed time in update: 11.310167
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34F90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE9A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34EA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F426D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F435E0>
# Elapsed time in update: 8.281715
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D4A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F343B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB3AE0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F426D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F362C0>
# Elapsed time in update: 8.086283
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3BD60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB0630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B810>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32310>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA8720>
# Elapsed time in update: 7.572094
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DE50>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB0720>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3CC20>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3BF90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F32450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F417C0>
# Elapsed time in update: 7.654027
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D810>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2F0E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F40F40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D1D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C4F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D400>
# Elapsed time in update: 7.333756
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D4F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F42900>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D090>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F42CC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F415E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E950>
# Elapsed time in update: 7.502107
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F42D60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D4A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB04A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3B630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F41540>
# Elapsed time in update: 8.430412
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34D10>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DB80>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB05E0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34EF0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F44770>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36E00>
# Elapsed time in update: 9.110612
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D9A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34D60>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34220>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAE950>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F44770>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F40680>
# Elapsed time in update: 8.235265
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D6D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F342C0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F348B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F418B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F45720>
# Elapsed time in update: 7.933125
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34310>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DA40>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36450>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2E3B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CA06D0>
# Elapsed time in update: 7.894037
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DEA0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F341D0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CAEA90>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F36C70>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2C400>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F3D400>
# Elapsed time in update: 7.231311
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34630>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2D9A0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x00000188F0CB04F0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F41130>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F45360>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F403B0>
# Elapsed time in update: 7.400772
# Iteration: 00000002/01000000
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F2DCC0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34BD0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F34B30>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F46590>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F413B0>
# 2 content size torch.Size([1, 256, 32, 32])
# 2 content size <built-in method size of Tensor object at 0x0000018880F454A0>

# %% [markdown]
# # Inference

# %%
import os
